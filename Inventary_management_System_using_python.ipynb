# %% [markdown]
# <a href="https://colab.research.google.com/github/Nileshkadam2002/colab/blob/main/Inventary_management_System_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inventary_management_System_using_python
# * 1. Creating the Inventory File

# %%
with open("Inventary.txt",'w') as file:
  file.write("1, chocklate, 5, 100\n")

# %%
dft=open("Inventary.txt","w")
dft.close()

# %%
dft=open("Inventary.txt","r")
txt=dft.read()
dft.close()

# %%
print(txt)
# Out:
# 1, Chocalate, 5, 100
# 2, Milky bar, 4, 300
# 3, candy, 3, 200
# 4, Vano, 4, 300

# %%
txt.split('\n')
# Out:
# ['1, Chocalate, 5, 100',
#  '2, Milky bar, 4, 300',
#  '3, candy, 3, 200',
#  '4, Vano, 4, 300']
